# %%
import math
import collections

import pandas as pd
import numpy as np
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
import requests
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'20',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0abf79e6-d82c-4a71-89be-7cf326325fb5',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
   #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#       id              name symbol                  slug  num_market_pairs  \
# 0      1           Bitcoin    BTC               bitcoin              9745
# 1   1027          Ethereum    ETH              ethereum              6091
# 2    825            Tether   USDT                tether             39750
# 3   3408          USD Coin   USDC              usd-coin              6226
# 4   1839               BNB    BNB                   bnb              1103
# 5   4687       Binance USD   BUSD           binance-usd              5093
# 6     52               XRP    XRP                   xrp               814
# 7   2010           Cardano    ADA               cardano               570
# 8   5426            Solana    SOL                solana               384
# 9     74          Dogecoin   DOGE              dogecoin               563
# 10  6636          Polkadot    DOT          polkadot-new               411
# 11  3890           Polygon  MATIC               polygon               487
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0abf79e6-d82c-4a71-89be-7cf326325fb5',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    #use this to export into csv
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df 
    
    #if not os.path.isfile(r'C:\Users\riddi\Desktop\seo\API.csv'):
       #df.to_csv(r'C:\Users\riddi\Desktop\seo\API.csv', header= 'column_names')
    #else:
       #df.to_csv(r'C:\Users\riddi\Desktop\seo\API.csv', mode = 'a', header=False)
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) 
exit()

# %%
df72 = pd.read_csv(r'C:\Users\riddi\Desktop\seo\API.csv')
df72
# Out:
#     Unnamed: 0    id         name symbol                  slug  \
# 0            0     1      Bitcoin    BTC               bitcoin
# 1            1  1027     Ethereum    ETH              ethereum
# 2            2   825       Tether   USDT                tether
# 3            3  3408     USD Coin   USDC              usd-coin
# 4            4  1839          BNB    BNB                   bnb
# 5            5    52          XRP    XRP                   xrp
# 6            6  4687  Binance USD   BUSD           binance-usd
# 7            7  2010      Cardano    ADA               cardano
# 8            8  5426       Solana    SOL                solana
# 9            9  6636     Polkadot    DOT          polkadot-new
# 10          10    74     Dogecoin   DOGE              dogecoin
# 11          11  3890      Polygon  MATIC               polygon
# 12          12  4943          Dai    DAI  multi-collateral-dai
# 13          13  5805    Avalanche   AVAX             avalanche
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' %x)

# %%
df72 = pd.read_csv(r'C:\Users\riddi\Desktop\seo\API.csv')
df72
# Out:
#     Unnamed: 0    id         name symbol                  slug  \
# 0            0     1      Bitcoin    BTC               bitcoin
# 1            1  1027     Ethereum    ETH              ethereum
# 2            2   825       Tether   USDT                tether
# 3            3  3408     USD Coin   USDC              usd-coin
# 4            4  1839          BNB    BNB                   bnb
# 5            5    52          XRP    XRP                   xrp
# 6            6  4687  Binance USD   BUSD           binance-usd
# 7            7  2010      Cardano    ADA               cardano
# 8            8  5426       Solana    SOL                solana
# 9            9  6636     Polkadot    DOT          polkadot-new
# 10          10    74     Dogecoin   DOGE              dogecoin
# 11          11  3890      Polygon  MATIC               polygon
# 12          12  4943          Dai    DAI  multi-collateral-dai
# 13          13  5805    Avalanche   AVAX             avalanche
# ...

# %%
df72.drop(["slug","num_market_pairs","date_added","tags","platform","self_reported_circulating_supply","self_reported_market_cap", "tvl_ratio","quote.USD.tvl","platform.id"],inplace = True, axis=1)

# %%
df72.set_index(keys = "name", inplace = True)
df72.head(3)
# Out:
#           Unnamed: 0    id symbol      slug  num_market_pairs  \
# name
# Bitcoin            0     1    BTC   bitcoin              9660
# Ethereum           1  1027    ETH  ethereum              5916
# Tether             2   825   USDT    tether             37450
#
#                         date_added  \
# name
# Bitcoin   2013-04-28T00:00:00.000Z
# Ethereum  2015-08-07T00:00:00.000Z
# Tether    2015-02-25T00:00:00.000Z
#
#                                                        tags     max_supply  \
# name
# Bitcoin   ['mineable', 'pow', 'sha-256', 'store-of-value... 21000000.00000
# Ethereum  ['mineable', 'pow', 'smart-contracts', 'ethere...            NaN
# Tether    ['payments', 'stablecoin', 'asset-backed-stabl...            NaN
#
#           circulating_supply      total_supply  platform  cmc_rank  \
# name
# Bitcoin       19113512.00000    19113512.00000       NaN         1
# Ethereum     121847565.24900   121847565.24900       NaN         2
# ...

# %%
times = pd.date_range(start = "2016-01-01", end = "2016-01-10", freq = "D")
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10'],
#               dtype='datetime64[ns]', freq='D')
